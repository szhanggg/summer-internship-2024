# CLDPROP_L2_ABI_GOES16.A2019255.2040.000.2022272181051.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2050.000.2022272181053.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2100.000.2022272181049.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2110.000.2022272181051.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2120.000.2022272181053.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2130.000.2022272181051.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2140.000.2022272181054.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2150.000.2022272181107.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2200.000.2022272181128.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2210.000.2022272181111.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2220.000.2022272181109.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2230.000.2022272181111.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2240.000.2022272181112.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2250.000.2022272181119.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2300.000.2022272181129.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2310.000.2022272181123.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2320.000.2022272181143.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2330.000.2022272181137.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2340.000.2022272181127.nc
# CLDPROP_L2_ABI_GOES16.A2019255.2350.000.2022272181137.nc

# %%
# PATH FOR SINGLE L2 FILE
L2PATH = "/css/geostationary/BackStage/CLDPROP_L2_ABI_GOES16/2019/255/CLDPROP_L2_ABI_GOES16.A2019255.2300.000.2022272181129.nc"

# %%
# LOAD AND VIEW L2 DATA
L2 = nc.Dataset(L2PATH, 'r')
L2
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Conventions: CF-1.6
#     format_version: 1
#     instrument: ABI
#     platform: G16
#     orbital_slot: GOES-East
#     title: Cloud Optical Properties
#     processing_level: L2
#     processing_version: v1.0
#     cdm_data_type: swath
#     creator_name: Dr. Steve Platnick
#     creator_email: steve.platnick@nasa.gov
#     creator_url: http://modis-atmos.gsfc.nasa.gov
#     project: NASA Himawari/GOES-R Atmosphere Discipline
#     keywords_vocabulary: NASA Global Change Master Directory (GCMD) Science Keywords
#     license: http://science.nasa.gov/earth-science/earth-science-data/data-information-policy/
#     stdname_vocabulary: NetCDF Climate and Forecast (CF) Metadata Convention
#     naming_authority: gov.nasa.gsfc.sci.atmos
#     Subset_File: No
#     source01: L1B names
#     source02: ./inputs-20190912.2300/OR_ABI-L1b-RadF-M6C02_G16_s20192552300166_e20192552309474_c20192552309517.nc
#     source03: ./inputs-20190912.2300/OR_ABI-L1b-RadF-M6C03_G16_s20192552300166_e20192552309474_c20192552309541.nc
#     source04: ./inputs-20190912.2300/OR_ABI-L1b-RadF-M6C05_G16_s20192552300166_e20192552309474_c20192552309535.nc
#     source05: ./inputs-20190912.2300/OR_ABI-L1b-RadF-M6C06_G16_s20192552300166_e20192552309480_c20192552309538.nc
#     source06: ./inputs-20190912.2300/OR_ABI-L1b-RadF-M6C07_G16_s20192552300166_e20192552309486_c20192552309546.nc
#     source07: ./inputs-20190912.2300/OR_ABI-L1b-RadF-M6C14_G16_s20192552300166_e20192552309474_c20192552309543.nc
#     source08: ./inputs-20190912.2300/OR_ABI-L1b-RadF-M6C15_G16_s20192552300166_e20192552309480_c20192552309557.nc
#     source09: ./inputs-20190912.2300/OR_ABI-L1b-RadF-M6C04_G16_s20192552300166_e20192552309474_c20192552309526.nc
#     source10: CM name
#     source11: ./inputs-20190912.2300/CLDIR_L2_ABI_GOES16.A2019255.2300.000.2022271164132.hdf
#     source12: Geolocation name
#     source13: CLDPROP_L2_ABI_GOES16.A2019255.2300.000.2022272181129.nc
#     source14: Output Name
#     source15: CLDPROP_L2_ABI_GOES16.A2019255.2300.000.2022272181129.nc
#     source16: NCEP name
#     source17: ./inputs-20190912.2300/gdas1.PGrbF00.190912.18z
#     source18: ./inputs-20190912.2300/gdas1.PGrbF00.190913.00z
#     source19: ICE name
#     source20: ./inputs-20190912.2300/eng.190912
#     source21: NISE name
#     source22: ./inputs-20190912.2300/NISE_SSMISF18_20190912.HDFEOS
#     source23: Forward Libraries
#     source24: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/Forward_Libraries/ABI_16_LUTS/lambertian_msr_ice_v6.ABI16.1.0.0.2020009221143.hdf
#     source25: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/Forward_Libraries/ABI_16_LUTS/lambertian_msr_water_v6.ABI16.1.0.1.2020028134333.hdf
#     source26: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/Forward_Libraries/ABI_16_LUTS/ocean_msr_ice_wspeed_3_v6.ABI16.1.0.0.2022153091714.hdf
#     source27: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/Forward_Libraries/ABI_16_LUTS/ocean_stddev_ice_wspeed_3_v6.ABI16.1.0.0.2020009223613.hdf
#     source28: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/Forward_Libraries/ABI_16_LUTS/ocean_msr_ice_wspeed_7_v6.ABI16.1.0.0.2022153091714.hdf
#     source29: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/Forward_Libraries/ABI_16_LUTS/ocean_stddev_ice_wspeed_7_v6.ABI16.1.0.0.2020009223613.hdf
#     source30: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/Forward_Libraries/ABI_16_LUTS/ocean_msr_ice_wspeed_15_v6.ABI16.1.0.0.2022153091714.hdf
#     source31: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/Forward_Libraries/ABI_16_LUTS/ocean_stddev_ice_wspeed_15_v6.ABI16.1.0.0.2020009223613.hdf
#     source32: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/Forward_Libraries/ABI_16_LUTS/ocean_msr_water_wspeed_3_v6.ABI16.1.0.1.2020028140102.hdf
#     source53: PFAAST Coefficients
#     source54: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/CT_Libraries/ABI_16/abibnd101.dat
#     source55: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/CT_Libraries/ABI_16/abidry101.dat
#     source56: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/CT_Libraries/ABI_16/abiozo101.dat
#     source57: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/CT_Libraries/ABI_16/abiwco101.dat
#     source58: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/CT_Libraries/ABI_16/abiwtl101.dat
#     source59: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/CT_Libraries/ABI_16/abiwts101.dat
#     source60: Emissivity
#     source61: /mnt/deliveredcode/deliveries/chimaera_staticdata/20220729-1/dist/project/staticdata/CT_Libraries/global_emiss_intABI_2005001.hdf
#     CHIMAERA_MODAWG_version: 7.0.0.12
#     Clear_Sky_Restoral_Status: y
#     Collection_4_Phase_Used: n
#     Ice_Phase_Forced: n
#     Water_Phase_Forced: n
#     Cox-Munk model enabled: y
#     dimensions(sizes): number_of_pixels(5424), number_of_lines(5424), number_of_failure_metrics(3), number_of_quality_assurance_bytes(4), number_of_wavelengths(6), number_of_ice_radii(12), number_of_liquid_radii(18)
#     variables(dimensions):
#     groups: geolocation_data, geophysical_data, cloud_model_data

# %%
# GET CLOUD TOP HIGH (+UNCERTAINTY) DATA, GET CLOUD MASK DATA
CTH = L2["geophysical_data"]["Cloud_Top_Height"]
CTHU = L2["geophysical_data"]["Cloud_Top_Height_Uncertainty"]
CM = L2["geophysical_data"]["Cloud_Mask"]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
CTH
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int16 Cloud_Top_Height(number_of_lines, number_of_pixels)
#     long_name: Cloud Top Height from NOAA CLAVR-x AWG algorithm
#     _FillValue: -999
#     valid_min: 0
#     valid_max: 18000
#     units: m
# path = /geophysical_data
# unlimited dimensions:
# current shape = (5424, 5424)
# filling on

# %%
plt.imshow(CTH)
plt.title("Cloud Top Height Variable")
plt.colorbar()

# %%
plt.hist(np.array(CTH).flatten())
plt.title("Histogram of Cloud Top Heights")
# Out:
# Text(0.5, 1.0, 'Histogram of Cloud Top Heights')

# %%
CTHU
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int16 Cloud_Top_Height_Uncertainty(number_of_lines, number_of_pixels)
#     long_name: Cloud Top Height uncertainty from NOAA CLAVR-x AWG algorithm
#     _FillValue: -999
#     valid_min: 0
#     valid_max: 20000
#     scale_factor: 0.10000000149011612
#     add_offset: 0.0
#     units: percent
# path = /geophysical_data
# unlimited dimensions:
# current shape = (5424, 5424)
# filling on

# %%
plt.imshow(CTHU)
plt.title("Uncertainty of Cloud Top Height")
plt.colorbar()

# %%
CM
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int8 Cloud_Mask(number_of_lines, number_of_pixels)
#     long_name: 2-d byte arrary from which cloud mask information can be extracted
#     description01:
#
#     description02:
#
#     description03:
#
#     description04: Bit fields within each byte are numbered from the left:
#
#     description05: 7, 6, 5, 4, 3, 2, 1, 0.
#
#     description06: The left-most bit (bit 7) is the most significant bit.
#
#     description07: The right-most bit (bit 0) is the least significant bit.
#
#     description08:
#
#     description09: Bit Field       Description                             Key
#
#     description10: ---------       -----------                             ---
#
#     description11:
#
#     description12: 0               Cloud Mask Flag                      0 = Not  determined
#
#     description13:                                                      1 = Determined
#
#     description14:
#
#     description15: 2, 1            Unobstructed FOV Quality Flag        00 = Cloudy
#
#     description16:                                                      01 = Uncertain
#
#     description17:                                                      10 = Probably  Clear
#
#     description18:                                                      11 = Confident  Clear
#
#     description19:                  PROCESSING PATH
#
#     description20:                 ---------------
#
#     description21: 3               Day or Night Path                    0 = Night  / 1 = Day
#
#     description22: 4               Sunglint Path                        0 = Yes    / 1 = No
#
#     description23: 5               Snow/Ice Background Path             0 = Yes    / 1 = No
#
#     description24: 7, 6            Land or Water Path                   00 = Water
#
#     description25:                                                      01 = Coastal
#
#     description26:                                                      10 = Desert
#
#     description27:                                                      11 = Land
#
# path = /geophysical_data
# unlimited dimensions:
# current shape = (5424, 5424)
# filling on, default _FillValue of -127 ignored

# %%
plt.imshow(CM)
plt.title("Cloud Mask Data") # SEE ABOVE HOW TO UNDERSTAND VALUES (BIT WISE)
plt.colorbar()

# %%
L2["geophysical_data"]
# Out:
# <class 'netCDF4._netCDF4.Group'>
# group /geophysical_data:
#     dimensions(sizes): number_of_reflectance_bands(5)
#     variables(dimensions): int16 Cloud_Top_Temperature(number_of_lines, number_of_pixels), int16 Cloud_Top_Height(number_of_lines, number_of_pixels), int16 Cloud_Top_Pressure(number_of_lines, number_of_pixels), int16 Cloud_Top_Pressure_Uncertainty(number_of_lines, number_of_pixels), int16 Cloud_Top_Temperature_Uncertainty(number_of_lines, number_of_pixels), int16 Cloud_Top_Height_Uncertainty(number_of_lines, number_of_pixels), int8 Cloud_Phase_Cloud_Top_Properties(number_of_lines, number_of_pixels), int16 Above_Cloud_Water_Vapor(number_of_lines, number_of_pixels), int16 IRW_Low_Cloud_Temperature_From_COP(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness_16(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness_1621(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness_39(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness_16_PCL(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness_PCL(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness_39_PCL(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness_1621_PCL(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius_16(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius_1621(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius_39(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius_16_PCL(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius_39_PCL(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius_PCL(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius_1621_PCL(number_of_lines, number_of_pixels), int16 Cloud_Water_Path_16(number_of_lines, number_of_pixels), int16 Cloud_Water_Path(number_of_lines, number_of_pixels), int16 Cloud_Water_Path_1621(number_of_lines, number_of_pixels), int16 Cloud_Water_Path_39(number_of_lines, number_of_pixels), int16 Cloud_Water_Path_16_PCL(number_of_lines, number_of_pixels), int16 Cloud_Water_Path_39_PCL(number_of_lines, number_of_pixels), int16 Cloud_Water_Path_1621_PCL(number_of_lines, number_of_pixels), int16 Cloud_Water_Path_PCL(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius_Uncertainty_16(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius_Uncertainty(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius_Uncertainty_1621(number_of_lines, number_of_pixels), int16 Cloud_Effective_Radius_Uncertainty_39(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness_Uncertainty_16(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness_Uncertainty(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness_Uncertainty_1621(number_of_lines, number_of_pixels), int16 Cloud_Optical_Thickness_Uncertainty_39(number_of_lines, number_of_pixels), int16 Cloud_Water_Path_Uncertainty_16(number_of_lines, number_of_pixels), int16 Cloud_Water_Path_Uncertainty(number_of_lines, number_of_pixels), int16 Cloud_Water_Path_Uncertainty_1621(number_of_lines, number_of_pixels), int16 Cloud_Water_Path_Uncertainty_39(number_of_lines, number_of_pixels), int8 Cloud_Phase_Optical_Properties(number_of_lines, number_of_pixels), int8 Failed_Ice_Retrieval_Residual_Type_21(number_of_lines, number_of_pixels), int8 Failed_Liquid_Retrieval_Residual_Type_21(number_of_lines, number_of_pixels), int16 Retrieval_Failure_Metric(number_of_lines, number_of_pixels, number_of_failure_metrics), int16 Retrieval_Failure_Metric_16(number_of_lines, number_of_pixels, number_of_failure_metrics), int16 Retrieval_Failure_Metric_1621(number_of_lines, number_of_pixels, number_of_failure_metrics), int16 Retrieval_Failure_Metric_39(number_of_lines, number_of_pixels, number_of_failure_metrics), int16 Atm_Corr_Refl(number_of_lines, number_of_pixels, number_of_reflectance_bands), int8 Cloud_Mask(number_of_lines, number_of_pixels), int8 Quality_Assurance(n ...
#     groups:

# %%
# ABI DATA PATH (EXAMPLE)
L1BPATH = "/css/geostationary/BackStage/GOES-16-ABI-L1B-FULLD/2019/255/23/OR_ABI-L1b-RadF-M6C01_G16_s20192552300166_e20192552309474_c20192552309530.nc"

# %%
L1B = nc.Dataset(L1BPATH, 'r')
L1B
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     naming_authority: gov.nesdis.noaa
#     Conventions: CF-1.7
#     standard_name_vocabulary: CF Standard Name Table (v35, 20 July 2016)
#     institution: DOC/NOAA/NESDIS > U.S. Department of Commerce, National Oceanic and Atmospheric Administration, National Environmental Satellite, Data, and Information Services
#     project: GOES
#     production_site: WCDAS
#     production_environment: OE
#     spatial_resolution: 1km at nadir
#     Metadata_Conventions: Unidata Dataset Discovery v1.0
#     orbital_slot: GOES-East
#     platform_ID: G16
#     instrument_type: GOES R Series Advanced Baseline Imager
#     scene_id: Full Disk
#     instrument_ID: FM1
#     title: ABI L1b Radiances
#     summary: Single reflective band ABI L1b Radiance Products are digital maps of outgoing radiance values at the top of the atmosphere for visible and near-IR bands.
#     keywords: SPECTRAL/ENGINEERING > VISIBLE WAVELENGTHS > VISIBLE RADIANCE
#     keywords_vocabulary: NASA Global Change Master Directory (GCMD) Earth Science Keywords, Version 7.0.0.0.0
#     iso_series_metadata_id: a70be540-c38b-11e0-962b-0800200c9a66
#     license: Unclassified data.  Access is restricted to approved users only.
#     processing_level: National Aeronautics and Space Administration (NASA) L1b
#     cdm_data_type: Image
#     dataset_name: OR_ABI-L1b-RadF-M6C01_G16_s20192552300166_e20192552309474_c20192552309530.nc
#     production_data_source: Realtime
#     timeline_id: ABI Mode 6
#     date_created: 2019-09-12T23:09:53.0Z
#     time_coverage_start: 2019-09-12T23:00:16.6Z
#     time_coverage_end: 2019-09-12T23:09:47.4Z
#     LUT_Filenames: SpaceLookParams(FM1A_CDRL79RevP_PR_08_01_01)-616659600.0.h5 QTableBand01(FM1A_CDRL79RevH_DO_07_00_00)-582860861.0.h5 CalTargetTimeIntervals(FM1A_CDRL79RevP_DO_08_00_01)-614334883.0.h5 BandSaturationLimits(FM1A_CDRL79RevH_DO_08_00_00)-600000000.0.h5 SolarSpaceLookParams(FM1A_CDRL79RevH_PR_08_01_01)-615377500.0.h5 DeadRowListParams(FM1A_CDRL79RevH_DO_08_00_00)-600000000.0.h5 Mirror_Record(FM1A_CDRL79RevG_DO_07_00_00)-582860861.0.h5 KalmanAstroConsts(FM1A_CDRL79RevH_DO_08_00_00)-600000000.0.xml KalmanFilterControls(FM1A_CDRL79RevJ_PR_08_01_01_1elementQb_highBeta_normalOps)-615377500.0.xml KalmanMeasMaxSensibles(FMAA_INT_ONLY_DO_08_00_00)-888.0.xml KalmanPreprocessorControls(FM1A_CDRL79RevJ_DO_07_00_00)-582860861.0.xml KalmanReferenceData(FM1A_CDRL79RevH_DO_08_00_00)-888.0.xml KalmanStarCatalogs(FM1A_CDRL79RevH_DO_08_00_00)-600000000.0.xml ABI_NavigationRDP_Band01(FM1A_CDRL79RevJ_DO_07_00_00)-582860861.0.xml ABI_NavigationParameters_Band01(FM1A_CDRL79RevH_DO_07_00_00)-582860861.0.xml ABI_ResamplingImplementation_Band01(FM1A_CDRL79RevH_DO_07_02_00)-602129336.0.xml ABI_ResamplingParameters_Band01(FM1A_CDRL79RevJ_DO_07_00_00)-582860861.0.xml StarLookParams(FM1A_CDRL79RevH_DO_08_00_00)-600000000.0.h5 StarDetectionParams(FM1A_CDRL79RevJ_DO_07_00_00)-582860861.0.xml ResamplingScaledConversion(FMAA_INT_ONLY_DO_08_00_00)-1111.0.xml BlockReleaseRegions(FMAA_INT_ONLY_DO_08_00_00)-2222.0.csv VNIR_RetrievalParameters(FM1A_CDRL79RevH_DO_08_00_00)-600000000.0.h5 ICM_ConversionConsts(FM1A_CDRL43-18_PR_08_02_01)-616659600.0.h5 ICM_SensorCoefficients(FM1A_TMABI_18_159_TMABI_18_533_PR_08_02_01)-616659600.0.h5
#     id: 4bc37692-69cb-4059-a9f4-35328d4e09f8
#     dimensions(sizes): y(10848), x(10848), number_of_time_bounds(2), band(1), number_of_image_bounds(2), num_star_looks(24)
#     variables(dimensions): int16 Rad(y, x), int8 DQF(y, x), float64 t(), int16 y(y), int16 x(x), float64 time_bounds(number_of_time_bounds), int32 goes_imager_projection(), float32 y_image(), float32 y_image_bounds(number_of_image_bounds), float32 x_image(), float32 x_image_bounds(number_of_image_bounds), float32 nominal_satellite_subpoint_lat(), float32 nominal_satellite_subpoint_lon(), float32 nominal_satellite_height(), float32 geospatial_lat_lon_extent(), int8 yaw_flip_flag(), int8 band_id(band), float32 band_wavelength(band), float32 esun(), float32 kappa0(), float32 planck_fk1(), float32 planck_fk2(), float32 planck_bc1(), float32 planck_bc2(), int32 valid_pixel_count(), int32 missing_pixel_count(), int32 saturated_pixel_count(), int32 undersaturated_pixel_count(), int32 focal_plane_temperature_threshold_exceeded_count(), float32 min_radiance_value_of_valid_pixels(), float32 max_radiance_value_of_valid_pixels(), float32 mean_radiance_value_of_valid_pixels(), float32 std_dev_radiance_value_of_valid_pixels(), float32 maximum_focal_plane_temperature(), float32 focal_plane_temperature_threshold_increasing(), float32 focal_plane_temperature_threshold_decreasing(), float32 percent_uncorrectable_L0_errors(), float32 earth_sun_distance_anomaly_in_AU(), int32 algorithm_dynamic_input_data_container(), int32 processing_parm_version_container(), int32 algorithm_product_version_container(), float64 t_star_look(num_star_looks), float32 band_wavelength_star_look(num_star_looks), int16 star_id(num_star_looks)
#     groups:

# %%
plt.imshow(L1B["Rad"])
plt.title("ABI Radience Data: C01")
plt.colorbar()

# %%
# BELOW IS THE FUNCTIONS AND CODE TO ACTUALLY LOAD THE L1B & L2 DATA

# %%
import os

# %%
def find_files(directory, prefix):
    """
    Find files in a directory that start with a specified prefix.

    Args:
        directory (str): The directory path to search for files.
        prefix (str): The prefix that the filenames should start with.

    Returns:
        list: A list of file paths matching the specified prefix.
    """
    matching_files = []
    for filename in os.listdir(directory):
        if filename.startswith(prefix):
            matching_files.append(os.path.join(directory, filename))
    return matching_files

# %%
def gather_files(YYYY, DDD, HH):
    """
    Args:
        YYYY (str): year in YYYY format
        DDD (str): day in DDD format
        HH (str): hour in HH format

    Returns:
        dict: A dictionary containing —
                ROOT_PATH: the base abi path

                YYYY: year
                DDD: day of year
                HH: hour

                00: files for minute 00 in hour
                ...
                50: filea for minute 50 in hour

                L200: cloud top height file (full path) for minute 00 in hour
                ...
                L250: cloud top height file (full path) for minute 50 in hour
    """

    ABI_ = {
        "ROOT_PATH": None,

        "YYYY": None,
        "DDD": None,
        "HH": None,

        "00": [],
        "10": [],
        "20": [],
        "30": [],
        "40": [],
        "50": [],

        "L200": None,
        "L210": None,
        "L220": None,
        "L230": None,
        "L240": None,
        "L250": None
    }

    _ABI_PATH_ = "/css/geostationary/BackStage/GOES-16-ABI-L1B-FULLD/" + YYYY + "/" + DDD + "/" + HH

    for filename in os.listdir(_ABI_PATH_):
        if ABI_["ROOT_PATH"] == None:
            ABI_["ROOT_PATH"] = _ABI_PATH_
            ABI_["YYYY"] = filename[27:31]
            ABI_["DDD"] = filename[31:34]
            ABI_["HH"] = filename[34:36]
        MM = filename[36:38]
        ABI_[f"{MM}"].append(filename)


    PREFIX = "CLDPROP_L2_ABI_GOES16.A" + ABI_["YYYY"] + ABI_["DDD"] + "." + ABI_["HH"]

    L2_PATH = f"/css/geostationary/BackStage/CLDPROP_L2_ABI_GOES16/" + ABI_["YYYY"] + "/" + ABI_["DDD"] + "/"

    for MM in ["00", "10", "20", "30", "40", "50"]:

        prefix = PREFIX + MM

        ABI_["L2" + MM] = find_files(L2_PATH, prefix)[0]

    return ABI_

# %%
def get_L1B_L2(abipaths, l2path, YYYY, DDD, HH):

    # ASSERT ALL ABI CHANNELS PRESENT !!!!!!!!!!!!!!!!!!!!
    assert len(abipaths) == 8, "NOT ALL ABI FILES LOCATED"
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


    # LOAD EACH ABI CHANNEL IMAGE
    CHANNELS = []
    ROOT = "/css/geostationary/BackStage/GOES-16-ABI-L1B-FULLD/"

    for file in abipaths:
        L1B = np.array(nc.Dataset(ROOT + "/" + YYYY + "/" + DDD + "/" + HH + "/" + file, 'r')["Rad"])
        CHANNEL = int(file[19:21])
        CHANNELS.append((L1B, CHANNEL))

    # SORT CHANNELS
    CHANNELS.sort(key=lambda x: x[1])
    CHANNELS = [C[0] for C in CHANNELS]

    T = []
    #RESIZE ALL CHANNELS TO SAME SIZE
    for C in CHANNELS:
        S = C.shape[0] // 5424
        if S != 1: C = C[::S, ::S]
        T.append(C)

    CHANNELS = T

    # STACK ABI CHANNELS INTO SINGLE IMAGE
    ABI = np.stack(CHANNELS, axis=2)

    # LOAD L2 IMAGE
    L2 = nc.Dataset(l2path, 'r')

    L2CT = np.array(L2["geophysical_data"]["Cloud_Top_Height"])
    L2UN = np.array(L2["geophysical_data"]["Cloud_Top_Height_Uncertainty"])
    L2CM = np.array(L2["geophysical_data"]["Cloud_Mask"])

    L2LAT = np.array(L2["geolocation_data"]["latitude"])
    L2LON = np.array(L2["geolocation_data"]["longitude"])

    return ABI, L2CT, L2UN, L2CM, L2LAT, L2LON

# %%
# TEST gather_files() FUNCTION
DATA = gather_files("2019", "220", "23")
DATA
# Out:
# {'ROOT_PATH': '/css/geostationary/BackStage/GOES-16-ABI-L1B-FULLD/2019/220/23',
#  'YYYY': '2019',
#  'DDD': '220',
#  'HH': '23',
#  '00': ['OR_ABI-L1b-RadF-M6C04_G16_s20192202300548_e20192202310256_c20192202310283.nc',
#   'OR_ABI-L1b-RadF-M6C07_G16_s20192202300548_e20192202310268_c20192202310325.nc',
#   'OR_ABI-L1b-RadF-M6C03_G16_s20192202300548_e20192202310256_c20192202310317.nc',
#   'OR_ABI-L1b-RadF-M6C05_G16_s20192202300548_e20192202310256_c20192202310321.nc',
#   'OR_ABI-L1b-RadF-M6C14_G16_s20192202300548_e20192202310256_c20192202310338.nc',
#   'OR_ABI-L1b-RadF-M6C01_G16_s20192202300548_e20192202310256_c20192202310313.nc',
#   'OR_ABI-L1b-RadF-M6C02_G16_s20192202340548_e20192202350256_c20192202350303.nc',
#   'OR_ABI-L1b-RadF-M6C03_G16_s20192202340548_e20192202350256_c20192202350320.nc',
#   'OR_ABI-L1b-RadF-M6C07_G16_s20192202340548_e20192202350268_c20192202350329.nc'],
#  '50': ['OR_ABI-L1b-RadF-M6C05_G16_s20192202350548_e20192210000256_c20192210000316.nc',
#   'OR_ABI-L1b-RadF-M6C02_G16_s20192202350548_e20192210000256_c20192210000307.nc',
#   'OR_ABI-L1b-RadF-M6C07_G16_s20192202350548_e20192210000268_c20192210000328.nc',
#   'OR_ABI-L1b-RadF-M6C14_G16_s20192202350548_e20192210000256_c20192210000343.nc',
#   'OR_ABI-L1b-RadF-M6C06_G16_s20192202350548_e20192210000262_c20192210000297.nc',
#   'OR_ABI-L1b-RadF-M6C03_G16_s20192202350548_e20192210000256_c20192210000320.nc',
#   'OR_ABI-L1b-RadF-M6C04_G16_s20192202350548_e20192210000256_c20192210000286.nc',
#   'OR_ABI-L1b-RadF-M6C01_G16_s20192202350548_e20192210000256_c20192210000313.nc'],
#  'L200': '/css/geostationary/BackStage/CLDPROP_L2_ABI_GOES16/2019/220/CLDPROP_L2_ABI_GOES16.A2019220.2300.000.2022274030153.nc',
#  'L210': '/css/geostationary/BackStage/CLDPROP_L2_ABI_GOES16/2019/220/CLDPROP_L2_ABI_GOES16.A2019220.2310.000.2022274030157.nc',
#  'L220': '/css/geostationary/BackStage/CLDPROP_L2_ABI_GOES16/2019/220/CLDPROP_L2_ABI_GOES16.A2019220.2320.000.2022274030203.nc',
#  'L230': '/css/geostationary/BackStage/CLDPROP_L2_ABI_GOES16/2019/220/CLDPROP_L2_ABI_GOES16.A2019220.2330.000.2022274030201.nc',
#  'L240': '/css/geostationary/BackStage/CLDPROP_L2_ABI_GOES16/2019/220/CLDPROP_L2_ABI_GOES16.A2019220.2340.000.2022274030153.nc',
#  'L250': '/css/geostationary/BackStage/CLDPROP_L2_ABI_GOES16/2019/220/CLDPROP_L2_ABI_GOES16.A2019220.2350.000.2022274030154.nc'}

# %%
# TEST DATA IS LOADED CORRECT W/ get_L1B_L2() FUNCTION
ABI, L2CT, L2UN, L2CM, L2LAT, L2LON = get_L1B_L2(DATA["00"], DATA["L200"], DATA["YYYY"], DATA["DDD"], DATA["HH"])

# %%
fig, ax = plt.subplots(2, 4, figsize=[10, 5])
C = 0
for i in range(2):
    for j in range(4):
        ax[i][j].axis("off")
        ax[i][j].imshow(ABI[800:5424-800, 800:5424-800, C])
        C += 1
fig.tight_layout()
print("BELOW ARE THE ABI CHANNELS LOADED IN PREVIOUS FUNCTIONS...")
# Out:
# BELOW ARE THE ABI CHANNELS LOADED IN PREVIOUS FUNCTIONS...

# %%
plt.imshow(L2CT[800:5424-800, 800:5424-800])
plt.axis("off")
print("BELOW IS THE L2 DATA LOADED IN PREVIOUS FUNCTIONS")
# Out:
# BELOW IS THE L2 DATA LOADED IN PREVIOUS FUNCTIONS

# %%
def get_uniform_sample(L2, N):
    # GET MASK FOR LOW CLOUDS AND HIGH CLOUDS
    no = L2 < 100
    low = np.logical_and(L2 > 100, L2 < 5000)
    high = L2 > 5000

    # CREATE COMBINED MASK TO SAMPLE COORDINATES FROM
    MASK = np.zeros_like(high).astype(float)
    MASK[low] = 0.5
    MASK[high] = 1

    # BOUNDS TO SAMPLE FROM
    BOUNDS = (1000, 5424-1000)

    # GENERATE 2*N COORDINATES AND ENSURE BALANCED DISTRIBUTION
    Xs = np.random.uniform(BOUNDS[0], BOUNDS[1], int(2 * N)).astype(int)
    Ys = np.random.uniform(BOUNDS[0], BOUNDS[1], int(2 * N)).astype(int)

    coordinate_pairs = list(zip(Xs, Ys))

    no_coordinates = []
    low_coordinates = []
    high_coordinates = []

    for (x, y) in coordinate_pairs:
        cloud_type = MASK[x, y]

        if cloud_type == 0:  # NONE
            no_coordinates.append((x, y))

        elif cloud_type == 0.5:  # LOW
            if len(low_coordinates) > (1.25 * len(high_coordinates)):
                continue
            else:
                low_coordinates.append((x, y))

        else: # cloud_type == 1, HIGH
            if len(high_coordinates) > (1.25 * len(low_coordinates)):
                continue
            else:
                high_coordinates.append((x, y))

    print("NUM NO CLOUD COORDS: ", len(no_coordinates))
    print("NUM HIGH CLOUD COORDS: ", len(high_coordinates))
    print("NUM LOW CLOUD COORDS: ", len(low_coordinates))

    high_coordinates.extend(low_coordinates)
    high_coordinates.extend(no_coordinates)

    return high_coordinates

# %%
# TEST get_uniform_sample() FUNCTION
Cs = get_uniform_sample(L2CT, 1000)
# Out:
# NUM NO CLOUD COORDS:  585
# NUM HIGH CLOUD COORDS:  524
# NUM LOW CLOUD COORDS:  656

# %%
def save_chips(ABI, L2_CLOUDTOP, L2_UNCERTAINTY, L2_CLOUDMASK, L2LAT, L2LON, COORDINATES, DEST_DIR, USRN, YYYY, DDD, HH, MM, TESTRUN=False):

    directory = f"/explore/nobackup/people/{USRN}/{DEST_DIR}/{YYYY}/{DDD}/{HH}/{MM}/"

    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f"DIR '{directory}' CREATED.")

    else:
        print(f"DIR '{directory}' ALREADY EXISTS.")

    for (x, y) in COORDINATES:
        # GET CHIP CENTERED ON COORDINATE
        chip = ABI[x-64:x+64, y-64:y+64, :]

        # GET ALL L2 INFORMATION
        CT = L2_CLOUDTOP[x-64:x+64, y-64:y+64]
        UN = L2_UNCERTAINTY[x-64:x+64, y-64:y+64]
        CM = L2_CLOUDMASK[x-64:x+64, y-64:y+64]

        # GET TAG INFORMATION
        L2V = L2_CLOUDTOP[x, y]

        if L2V < 100: tag = "NO"
        elif L2V < 5000: tag = "LOW"
        else: tag = "HIGH"

        single_stats = {"cloud_type": tag,
                 "latitude": L2LAT[x, y],
                 "longitude": L2LON[x, y],
                 "time": f"{YYYY}-{DDD}-{HH}-{MM}",
                }

        additional_data = {
                "cloud_top": CT,
                "cloud_top_uncertainty": UN,
                "cloud_mask": CM,
                }



        filename = "ABICHIP_L1B_L2_" + YYYY + DDD + HH + "_" + str(x) + "_" + str(y)

        np.savez(directory+filename, ABI=chip, L2=additional_data, EXTRA=single_stats)

        if TESTRUN:
            print("SAVED: ", filename, "IN: ", directory)
            break

    print("NUM SAVED CHIPS:", len(COORDINATES), "IN:", directory)

# %%
def generate_chips(YYYY, DDD, HH, MM, DEST_DIR, USRN):
    DATA = gather_files(YYYY, DDD, HH)
    ABI, L2CT, L2UN, L2CM, L2LAT, L2LON = get_L1B_L2(DATA[MM], DATA["L2"+MM], DATA["YYYY"], DATA["DDD"], DATA["HH"])
    COORDS = get_uniform_sample(L2CT, 1000)
    save_chips(ABI, L2CT, L2UN, L2CM, L2LAT, L2LON, COORDS, DEST_DIR, USRN, DATA["YYYY"], DATA["DDD"], DATA["HH"], MM)

# %%
generate_chips("2019", "226", "23", "00", "L2_chips", "dhubert1")
# Out:
# NUM NO CLOUD COORDS:  556
# NUM HIGH CLOUD COORDS:  649
# NUM LOW CLOUD COORDS:  731
# DIR '/explore/nobackup/people/dhubert1/L2_chips/2019/226/23/' CREATED.
# NUM SAVED CHIPS: 1936 IN: /explore/nobackup/people/dhubert1/L2_chips/2019/226/23/

# %% [markdown]
# ```
# THE BELOW CODE HAS NOT BEEN RUN AND MAY PRODUCE ERRORS,
# USE IT AS A GUIDE TO UPDATE THE ABOVE generate_chips() FUNCTION
#
# IT SHOULD BE FULLY FUNCTIONAL THOUGH...
# ```

# %%
def generate_chips(YYYY, DDD, HH, DEST_DIR, USRN):
    assert False, "DOUBLE CHECK CODE THIS FUNCTION IS UNTESTED" # STOPS FUNCTION FROM RUNNING UNTIL MANUALLY REMOVED
    DATA = gather_files(YYYY, DDD, HH)
    # LOOP THROUGH MINUTES
    for MM in ["00", "10", "20", "30", "40", "50"]:
        ABI, L2CT, L2UN, L2CM, L2LAT, L2LON = get_L1B_L2(DATA[MM], DATA["L2"+MM], DATA["YYYY"], DATA["DDD"], DATA["HH"])
        COORDS = get_uniform_sample(L2CT, 1000) # 1000 IS NUMBER OF CHIPS PER FILESET
        save_chips(ABI, L2CT, L2UN, L2CM, L2LAT, L2LON, COORDS, DEST_DIR, USRN, DATA["YYYY"], DATA["DDD"], DATA["HH"], MM)

# %% [markdown]
# ```
# EXAMPLE PROCESS FOR ENTIRE DAY,
# PSUEDOCODE!
# ```

# %%
YYYY = _
DDD = _
DEST_DIR = _
USRN = _

# FOR EACH HOUR
for HH in [f"{HH:02}" for HH in range(23)]:
    # CHECK DIRECTORY EXISTS
    generate_chips(YYYY, DDD, HH, DEST_DIR, USRN)

# APPLY MORE OUTER LOOPS FOR MULTIPLE DAYS // YEARS

# IT MAY BE IMPORTANT TO CHANGE ASSERTIONS TO RETURN NULLS IN ORDER TO NOT HALT SCRIPT

# %% [markdown]
# ```
# SAMPLE CODE FOR LOADING DATA
# ```

# %%
path_to_file = "NOOT/NOOT/NOOTNOOT.npz"

file = np.load(path_to_file, allow_pickle=True)

ABI_data = file["ABI"] # np.array
L2_data = file["L2"].item() # DICTIONARY OF {"cloud_top": np.array, "cloud_top_uncertainty": np.array, "cloud_mask": np.array}
meta_data = file["EXTRA"].item # DICTIONARY WITH KEYS "latitude", "longitude", (of center point), "time"
